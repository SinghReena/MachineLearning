# %% [markdown]
# <a href="https://colab.research.google.com/github/SinghReena/MachineLearning/blob/master/Class_3_(print_function%2C_Single%2C_double%2C_triple_Quotes%2C_Decision_making%2C_Basic_Descriptive_Statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *Function print and an Intro to Single- and Double- Quoted Strings*

# %% [markdown]
# **Function print**

# %% [markdown]
# The built-in print function displays its argument(s) as a line of text:

# %%
print('Intro to Python for Computer Science and Data Science')
# Out:
# Intro to Python for Computer Science and Data Science

# %% [markdown]
# The argument 'Intro to Python for Computer Science and Data Science' is a string--- a sequence of characters enclosed in single quotes('). You also may enclose a string in double quotes("), as in

# %%
print("Intro to Python for Computer Science and Data Science")
# Out:
# Intro to Python for Computer Science and Data Science

# %% [markdown]
# **Printing a Comma-Separated List of Items**

# %% [markdown]
# The print function can receive a comma-separated list of arguments, as in

# %%
print('Intro', 'to', 'Python', 'for', 'Computer', 'Science', 'and', 'Data Science')
# Out:
# Intro to Python for Computer Science and Data Science

# %% [markdown]
# The above print statement showed a comma-separated list of strings, but the values can be of any type.

# %% [markdown]
# **Printing many Lines of Text with One Statement**

# %% [markdown]
# When a backslash (\) appears in a string, it is known as the escape character. The backslash and the character immediately following it form an escape sequence.

# %%
print('Intro to Python\n for \nComputer Science\n\n and Data Science')
# Out:
# Intro to Python
#  for
# Computer Science
#
#  and Data Science

# %% [markdown]
# Placing two newline characters back-to-back displays a blank line.

# %% [markdown]
# **Escape sequences**

# %% [markdown]
# ![Escape sequences.png](data:image/png;base64,...)

# %% [markdown]
# **Ignoring a Line Break in a Long String**

# %% [markdown]
# You may also split a long string(or a long statement) over several lines by using the \continuation character as the last character on a line to ignore the line break.

# %%
print('This is a longer string, so we \
split it over two lines')
# Out:
# This is a longer string, so we split it over two lines

# %% [markdown]
# The interpreter reassembles the string's parts into a single string with no line break. Though the backslash character in the preceding snippet is inside a string, it is not the escape character because another character does not follow it.

# %% [markdown]
# **Printing the Value of an Expression**

# %% [markdown]
# Calculations can be performed in print statements

# %%
print('Multiplication is', 6*3)
# Out:
# Multiplication is 18

# %% [markdown]
# *Triple-Quoted Strings*

# %% [markdown]
# Triple-quoted strings begin and end with three double quotes(""") or three single quotes(''').The *Style Guide for Python Code * recommends three double quotes("""). Use these to create:
#
# 1. multiline strings,
#
# 2. strings containing single or double quotes and
#
# 3. docstrings, which are the recommended way to document the purposes of certain program components.

# %% [markdown]
# **Including Quotes in Strings**

# %% [markdown]
# In a string delimited by single quotes, you may include double-quote characters:

# %%
print('Display "hi" in quotes')
# Out:
# Display "hi" in quotes

# %% [markdown]
# but not single quotes:

# %%
print('Display 'hi' in quotes')
# Out:
#   File "<ipython-input-2-19bf596ccf72>", line 1
#     print('Display 'hi' in quotes')
#                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# unless you use the \' escape sequence:

# %%
print('Display \'hi\' in quotes')
# Out:
# Display 'hi' in quotes

# %% [markdown]
# A string delimited by double quotes may include single quote characters:

# %%
print("Display the name O'Brien")
# Out:
# Display the name O'Brien

# %% [markdown]
# but not double quotes, unless you use the \" escape sequence:

# %%
print("Display \"hi\" in quotes")
# Out:
# Display "hi" in quotes

# %% [markdown]
# To avoid using \' and \" inside strings, you can enclose such strings in triple quotes:

# %%
print("""Display "hi" and 'bye' in quotes""")
# Out:
# Display "hi" and 'bye' in quotes

# %% [markdown]
# *Multiline Strings*

# %% [markdown]
# The following snippet assigns a multiline triple-quoted string to triple_quoted_string:

# %%
triple_quoted_string = """This is a triple-quoted 
  string that spans two lines"""
print(triple_quoted_string)
# Out:
# This is a triple-quoted
#   string that spans two lines

# %% [markdown]
# The string is incomplete because we did not type the closing """ before we pressed Enter. So, IPython displays a continuation prompt ...: at which you can input the multiline string’s next line. This continues until you enter the ending """ and press Enter.

# %% [markdown]
# Python stores multiline strings with embedded newline escape sequences. When we evaluate triple_quoted_string rather than printing it, IPython displays the string in single quotes with a \n character where you pressed Enter. The quotes IPython displays indicate that triple_quoted_string is a string—they’re not part of the string’s contents:

# %%
triple_quoted_string = """This is a triple-quoted
string that spans two lines"""
(triple_quoted_string)
# Out:
# 'This is a triple-quoted\nstring that spans two lines'

# %% [markdown]
# *Decision Making: The if Statement and Comparison Operators*

# %% [markdown]
# A condition is a Boolean expression with the value True or False. The following determines whether 7 is greater than 4 and whether 7 is less than 4:

# %%
7 > 4
# Out:
# True

# %%
7 < 4
# Out:
# False

# %% [markdown]
# True and False are keywords—words that Python reserves for its language features. Using a keyword as an identifier causes a SyntaxError. True and False are each capitalized.

# %% [markdown]
# Create conditions using the comparison operators in the table

# %% [markdown]
# ![comparison operators.png](data:image/png;base64,...)

# %% [markdown]
# Operators >, <, >= and <= all have the same precedence. Operators == and != both have the same precedence, which is lower than that of >, <, >= and <=. A syntax error occurs when any of the operators ==, !=, >= and <= contains spaces between its pair of symbols:

# %%
7 > = 4
# Out:
#   File "<ipython-input-11-5c6e2897f3b3>", line 1
#     7 > = 4
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# Another syntax error occurs if you reverse the symbols in the operators !=, >= and <= (by writing them as =!, => and =<).

# %%
7 => 4

# %% [markdown]
# **Introducing scripts : Making decisions with the if Statement**

# %%
"""Comparing integers using if statements and comparison operators."""
 
print('Enter two integers, and I will tell you',
        'the relationships they satisfy.')
 
  # read first integer
number1 = int(input('Enter first integer: '))
 
 # read second integer
number2 = int(input('Enter second integer: '))

if number1 == number2:
     print(number1, 'is equal to', number2)

if number1 != number2:
     print(number1, 'is not equal to', number2)

if number1 < number2:
     print(number1, 'is less than', number2)

if number1 > number2:
     print(number1, 'is greater than', number2)

if number1 <= number2:
     print(number1, 'is less than or equal to', number2)

if number1 >= number2:
   print(number1, 'is greater than or equal to', number2)

# %% [markdown]
# **Confusing == and =**

# %% [markdown]
# Using the assignment symbol (=) instead of the equality operator (==) in an if statement’s condition is a common syntax error. To help avoid this, read == as “is equal to” and = as “is assigned.”

# %% [markdown]
# **Chaining Comparisons**

# %% [markdown]
# You can chain comparisons to check whether a value is in a range. The following comparison determines whether x is in the range 1 through 5, inclusive:

# %%
x=3
1 <= x <= 5

# %%
x=10
1 <= x <=5

# %% [markdown]
# **Precedence of the Operators **

# %% [markdown]
# ![All operators.png](data:image/png;base64,...)

# %% [markdown]
# The table lists the operators top-to-bottom in decreasing order of precedence.

# %% [markdown]
# **Objects and Dynamic Typing**

# %% [markdown]
# Values such as 7 (an integer), 4.1 (a floating-point number) and 'dog' are all objects. Every object has a type and a value:

# %%
type(7)
# Out:
# int

# %%
type(4.1)
# Out:
# float

# %%
type('dog')
# Out:
# str

# %% [markdown]
# An object’s value is the data stored in the object. The snippets above show objects of Python built-in types int (for integers), float (for floating-point numbers) and str (for strings).

# %% [markdown]
# *Variables Refer to Objects*

# %% [markdown]
# Assigning an object to a variable binds (associates) that variable’s name to the object. As you’ve seen, you can then use the variable in your code to access the object’s value:

# %%
x=7
x+10
x
# Out:
# 7

# %% [markdown]
# The variable x refers to the integer object containing 7. It does not change x's value.
#
# You can change the x's value as follows

# %%
x=7
x=x+10
x
# Out:
# 17

# %% [markdown]
# *Dynamic Typing*

# %% [markdown]
# Python uses dynamic typing—it determines the type of the object a variable refers to while executing your code. We can show this by rebinding the variable x to different objects and checking their types:

# %%
x=8
print(type(x))
x=9.6
print(type(x))
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# *Garbage Collection*

# %% [markdown]
# Python creates objects in memory and removes them from memory as necessary.  The variable x now refers to a float object. The integer object is no longer bound to a variable.Python automatically removes such objects from memory. This process—called garbage collection—helps ensure that memory is available for new objects you create.

# %% [markdown]
# **Intro to Data Science: Basic Descriptive Statistics**

# %% [markdown]
# In data science, you’ll often use statistics to describe and summarize your data. Here, we begin by introducing several such descriptive statistics, including:
#
# minimum—the smallest value in a collection of values.
#
# maximum—the largest value in a collection of values.
#
# range—the range of values from the minimum to the maximum.

# %%
min(12,90,567)
# Out:
# 12

# %%
max(12,90,567)
# Out:
# 567

# %%
print("Range:",min(12,90,567),"-",max(12,90,567))
# Out:
# Range: 12 - 567
